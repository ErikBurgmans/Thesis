# %%
import math
import numpy as np
import pandas as pd
import os
import glob
import pickle
import xgboost as xgb
import numpy as np
import pandas as pd
from sklearn.metrics import mutual_info_score

# %%
def split_data_labels (csv_file):
    df = pd.read_csv(csv_file)
    #display(df)
    x_array = df.iloc[:,1:-6]
    #print(df1)
    y_array = df.iloc[:,230:]
    return x_array, y_array
    #print(result)

# %%
csv_file = "complete_CSV_Train.csv"
x_train, y_train = split_data_labels(csv_file)
csv_file = "complete_CSV_validation.csv"
x_test, y_test = split_data_labels(csv_file)

# %%
from xgboost import XGBRegressor

params = {'colsample_bytree': 0.3, 'learning_rate': 0.01, 'max_depth': 6, 'n_estimators': 1000}

xgbr = XGBRegressor(colsample_bytree = 0.3, learning_rate = 0.01, max_depth = 6, n_estimators = 1000, verbosity=0)
print(xgbr)
# Out:
# XGBRegressor(base_score=None, booster=None, colsample_bylevel=None,
#              colsample_bynode=None, colsample_bytree=0.3, gamma=None,
#              gpu_id=None, importance_type='gain', interaction_constraints=None,
#              learning_rate=0.01, max_delta_step=None, max_depth=6,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=1000, n_jobs=None, num_parallel_tree=None,
#              random_state=None, reg_alpha=None, reg_lambda=None,
#              scale_pos_weight=None, subsample=None, tree_method=None,
#              validate_parameters=None, verbosity=0)

# %%
xgbr.fit(x_train, y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.3, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.01, max_delta_step=0, max_depth=6,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=1000, n_jobs=8, num_parallel_tree=1, random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=0)

# %%
score = xgbr.score(x_train, y_train)
print(score)
# Out:
# 0.7819262452824136

# %%
from xgboost import XGBRegressor
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error


cv_score = cross_val_score(xgbr, x_train, y_train, cv=10)
print("CV mean score:", cv_score.mean())
# Out:
# CV mean score: 0.2688914423622055

# %%
ypred = xgbr.predict(x_test)
mae = mean_absolute_error(y_test, ypred)

print("1-MAE", 1-mae)
# Out:
# 1-MAE 0.9015458303533286

# %%
print(ypred)
print(y_test)
# Out:
# [0.50280493 0.45715475 0.56857353 ... 0.42211103 0.4999354  0.4748322 ]
#       Interview
# 0      0.654206
# 1      0.644860
# 2      0.457944
# 3      0.364486
# 4      0.607477
# ...         ...
# 1995   0.682243
# 1996   0.794393
# 1997   0.205607
# 1998   0.299065
# 1999   0.308411
#
# [2000 rows x 1 columns]

# %%
test1 = np.mean(np.array(y_train))

# %%
print(test1)
# Out:
# 0.5037803738317757

# %%
test2 = np.array(y_test)
print(test2)
# Out:
# [[0.65420561]
#  [0.64485981]
#  [0.45794393]
#  ...
#  [0.20560748]
#  [0.29906542]
#  [0.30841121]]

# %%
test3 = abs(test2-test1)

# %%
test4 = np.mean(test3)
print(test4)
print(1-test4)
# Out:
# 0.1169892336448598
# 0.8830107663551402

# %%
def split_data_labels_openness (csv_file):
    df = pd.read_csv(csv_file)
    #display(df)
    x_array = df.iloc[:,1:-6]
    #print(df1)
    y_array = df.iloc[:,225]
    return x_array, y_array
    #print(result)

# %%
csv_file = "complete_CSV_Train.csv"
x_train, y_train = split_data_labels_openness(csv_file)
csv_file = "complete_CSV_validation.csv"
x_test, y_test = split_data_labels_openness(csv_file)

# %%
print(y_train)
# Out:
# 0       0.544444
# 1       0.733333
# 2       0.788889
# 3       0.533333
# 4       0.577778
#           ...
# 5995    0.733333
# 5996    0.500000
# 5997    0.544444
# 5998    0.588889
# 5999    0.477778
# Name: Openness, Length: 6000, dtype: float64

# %%
import pandas as pd
import xgboost as xgb
from sklearn.model_selection import GridSearchCV

data = pd.read_csv("complete_CSV_Train.csv")

X, y = x_train, y_train
    
params = { 'max_depth': [3,6,10],
           'learning_rate': [0.01, 0.05, 0.1],
           'n_estimators': [100, 500, 1000],
           'colsample_bytree': [0.3, 0.7]}

xgbr = xgb.XGBRegressor(seed = 20)
clf = GridSearchCV(estimator=xgbr, 
                   param_grid=params,
                   scoring='neg_mean_absolute_error', 
                   verbose=1)

clf.fit(X, y)
print("Best parameters:", clf.best_params_)
print("Lowest mae: ", (-clf.best_score_)**(1/2.0))
# Out:
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# Best parameters: {'colsample_bytree': 0.3, 'learning_rate': 0.01, 'max_depth': 6, 'n_estimators': 1000}
# Lowest mae:  0.3149356331229591

# %%
from xgboost import XGBRegressor

xgbr = XGBRegressor(colsample_bytree = 0.3, learning_rate = 0.01, max_depth = 6, n_estimators = 1000, verbosity=0)
print(xgbr)
# Out:
# XGBRegressor(base_score=None, booster=None, colsample_bylevel=None,
#              colsample_bynode=None, colsample_bytree=0.3, gamma=None,
#              gpu_id=None, importance_type='gain', interaction_constraints=None,
#              learning_rate=0.01, max_delta_step=None, max_depth=6,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=1000, n_jobs=None, num_parallel_tree=None,
#              random_state=None, reg_alpha=None, reg_lambda=None,
#              scale_pos_weight=None, subsample=None, tree_method=None,
#              validate_parameters=None, verbosity=0)

# %%
xgbr.fit(x_train, y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.3, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.01, max_delta_step=0, max_depth=6,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=1000, n_jobs=8, num_parallel_tree=1, random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=0)

# %%
score = xgbr.score(x_train, y_train)
print(score)
# Out:
# 0.7896323547250335

# %%
from xgboost import XGBRegressor
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error


cv_score = cross_val_score(xgbr, x_train, y_train, cv=10)
print("CV mean score:", cv_score.mean())
# Out:
# CV mean score: 0.28008235605540993

# %%
ypred = xgbr.predict(x_test)
mae = mean_absolute_error(y_test, ypred)

print("1-MAE", 1-mae)
# Out:
# 1-MAE 0.9035643616424667

# %%
def split_data_labels_conscientiousness (csv_file):
    df = pd.read_csv(csv_file)
    #display(df)
    x_array = df.iloc[:,1:-6]
    #print(df1)
    y_array = df.iloc[:,226]
    return x_array, y_array
    #print(result)

# %%
csv_file = "complete_CSV_Train.csv"
x_train, y_train = split_data_labels_conscientiousness(csv_file)
csv_file = "complete_CSV_validation.csv"
x_test, y_test = split_data_labels_conscientiousness(csv_file)

# %%
import pandas as pd
import xgboost as xgb
from sklearn.model_selection import GridSearchCV

data = pd.read_csv("complete_CSV_Train.csv")

X, y = x_train, y_train
    
params = { 'max_depth': [3,6,10],
           'learning_rate': [0.01, 0.05, 0.1],
           'n_estimators': [100, 500, 1000],
           'colsample_bytree': [0.3, 0.7]}

xgbr = xgb.XGBRegressor(seed = 20)
clf = GridSearchCV(estimator=xgbr, 
                   param_grid=params,
                   scoring='neg_mean_absolute_error', 
                   verbose=1)

clf.fit(X, y)
print("Best parameters:", clf.best_params_)
print("Lowest mae: ", (-clf.best_score_)**(1/2.0))
# Out:
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# Best parameters: {'colsample_bytree': 0.7, 'learning_rate': 0.05, 'max_depth': 6, 'n_estimators': 1000}
# Lowest mae:  0.3280277435990194

# %%
from xgboost import XGBRegressor

xgbr = XGBRegressor(colsample_bytree = 0.7, learning_rate = 0.05, max_depth = 6, n_estimators = 1000, verbosity=0)
print(xgbr)
# Out:
# XGBRegressor(base_score=None, booster=None, colsample_bylevel=None,
#              colsample_bynode=None, colsample_bytree=0.7, gamma=None,
#              gpu_id=None, importance_type='gain', interaction_constraints=None,
#              learning_rate=0.05, max_delta_step=None, max_depth=6,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=1000, n_jobs=None, num_parallel_tree=None,
#              random_state=None, reg_alpha=None, reg_lambda=None,
#              scale_pos_weight=None, subsample=None, tree_method=None,
#              validate_parameters=None, verbosity=0)

# %%
xgbr.fit(x_train, y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.7, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.05, max_delta_step=0, max_depth=6,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=1000, n_jobs=8, num_parallel_tree=1, random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=0)

# %%
score = xgbr.score(x_train, y_train)
print(score)
# Out:
# 0.9942447537383657

# %%
from xgboost import XGBRegressor
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error


cv_score = cross_val_score(xgbr, x_train, y_train, cv=10)
print("CV mean score:", cv_score.mean())
# Out:
# CV mean score: 0.25904720491602495

# %%
ypred = xgbr.predict(x_test)
mae = mean_absolute_error(y_test, ypred)

print("1-MAE", 1-mae)
# Out:
# 1-MAE 0.8959002187767798

# %%
def split_data_labels_extroversion (csv_file):
    df = pd.read_csv(csv_file)
    #display(df)
    x_array = df.iloc[:,1:-6]
    #print(df1)
    y_array = df.iloc[:,227]
    return x_array, y_array
    #print(result)

# %%
csv_file = "complete_CSV_Train.csv"
x_train, y_train = split_data_labels_extroversion(csv_file)
csv_file = "complete_CSV_validation.csv"
x_test, y_test = split_data_labels_extroversion(csv_file)

# %%
import pandas as pd
import xgboost as xgb
from sklearn.model_selection import GridSearchCV

data = pd.read_csv("complete_CSV_Train.csv")

X, y = x_train, y_train
    
params = { 'max_depth': [3,6,10],
           'learning_rate': [0.01, 0.05, 0.1],
           'n_estimators': [100, 500, 1000],
           'colsample_bytree': [0.3, 0.7]}

xgbr = xgb.XGBRegressor(seed = 20)
clf = GridSearchCV(estimator=xgbr, 
                   param_grid=params,
                   scoring='neg_mean_absolute_error', 
                   verbose=1)

clf.fit(X, y)
print("Best parameters:", clf.best_params_)
print("Lowest mae: ", (-clf.best_score_)**(1/2.0))
# Out:
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# Best parameters: {'colsample_bytree': 0.3, 'learning_rate': 0.01, 'max_depth': 6, 'n_estimators': 1000}
# Lowest mae:  0.3116579332743541

# %%
from xgboost import XGBRegressor

xgbr = XGBRegressor(colsample_bytree = 0.3, learning_rate = 0.01, max_depth = 6, n_estimators = 1000, verbosity=0)
print(xgbr)
# Out:
# XGBRegressor(base_score=None, booster=None, colsample_bylevel=None,
#              colsample_bynode=None, colsample_bytree=0.3, gamma=None,
#              gpu_id=None, importance_type='gain', interaction_constraints=None,
#              learning_rate=0.01, max_delta_step=None, max_depth=6,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=1000, n_jobs=None, num_parallel_tree=None,
#              random_state=None, reg_alpha=None, reg_lambda=None,
#              scale_pos_weight=None, subsample=None, tree_method=None,
#              validate_parameters=None, verbosity=0)

# %%
xgbr.fit(x_train, y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.3, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.01, max_delta_step=0, max_depth=6,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=1000, n_jobs=8, num_parallel_tree=1, random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=0)

# %%
score = xgbr.score(x_train, y_train)
print(score)
# Out:
# 0.8132769992838438

# %%
from xgboost import XGBRegressor
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error


cv_score = cross_val_score(xgbr, x_train, y_train, cv=10)
print("CV mean score:", cv_score.mean())
# Out:
# CV mean score: 0.3563357890050324

# %%
ypred = xgbr.predict(x_test)
mae = mean_absolute_error(y_test, ypred)

print("1-MAE", 1-mae)
# Out:
# 1-MAE 0.9062002962158523

# %%
def split_data_labels_agreeableness (csv_file):
    df = pd.read_csv(csv_file)
    #display(df)
    x_array = df.iloc[:,1:-6]
    #print(df1)
    y_array = df.iloc[:,228]
    return x_array, y_array
    #print(result)

# %%
csv_file = "complete_CSV_Train.csv"
x_train, y_train = split_data_labels_extroversion(csv_file)
csv_file = "complete_CSV_validation.csv"
x_test, y_test = split_data_labels_extroversion(csv_file)

# %%
import pandas as pd
import xgboost as xgb
from sklearn.model_selection import GridSearchCV

data = pd.read_csv("complete_CSV_Train.csv")

X, y = x_train, y_train
    
params = { 'max_depth': [3,6,10],
           'learning_rate': [0.01, 0.05, 0.1],
           'n_estimators': [100, 500, 1000],
           'colsample_bytree': [0.3, 0.7]}

xgbr = xgb.XGBRegressor(seed = 20)
clf = GridSearchCV(estimator=xgbr, 
                   param_grid=params,
                   scoring='neg_mean_absolute_error', 
                   verbose=1)

clf.fit(X, y)
print("Best parameters:", clf.best_params_)
print("Lowest mae: ", (-clf.best_score_)**(1/2.0))
# Out:
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# Best parameters: {'colsample_bytree': 0.3, 'learning_rate': 0.01, 'max_depth': 6, 'n_estimators': 1000}
# Lowest mae:  0.3116579332743541

# %%
from xgboost import XGBRegressor

xgbr = XGBRegressor(colsample_bytree = 0.3, learning_rate = 0.01, max_depth = 6, n_estimators = 1000, verbosity=0)
print(xgbr)
# Out:
# XGBRegressor(base_score=None, booster=None, colsample_bylevel=None,
#              colsample_bynode=None, colsample_bytree=0.3, gamma=None,
#              gpu_id=None, importance_type='gain', interaction_constraints=None,
#              learning_rate=0.01, max_delta_step=None, max_depth=6,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=1000, n_jobs=None, num_parallel_tree=None,
#              random_state=None, reg_alpha=None, reg_lambda=None,
#              scale_pos_weight=None, subsample=None, tree_method=None,
#              validate_parameters=None, verbosity=0)

# %%
xgbr.fit(x_train, y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.3, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.01, max_delta_step=0, max_depth=6,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=1000, n_jobs=8, num_parallel_tree=1, random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=0)

# %%
score = xgbr.score(x_train, y_train)
print(score)
# Out:
# 0.8132769992838438

# %%
from xgboost import XGBRegressor
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error


cv_score = cross_val_score(xgbr, x_train, y_train, cv=10)
print("CV mean score:", cv_score.mean())
# Out:
# CV mean score: 0.3563357890050324

# %%
ypred = xgbr.predict(x_test)
mae = mean_absolute_error(y_test, ypred)

print("1-MAE", 1-mae)
# Out:
# 1-MAE 0.9062002962158523

# %%
def split_data_labels_neuroticism (csv_file):
    df = pd.read_csv(csv_file)
    #display(df)
    x_array = df.iloc[:,1:-6]
    #print(df1)
    y_array = df.iloc[:,229]
    return x_array, y_array
    #print(result)

# %%
csv_file = "complete_CSV_Train.csv"
x_train, y_train = split_data_labels_neuroticism(csv_file)
csv_file = "complete_CSV_validation.csv"
x_test, y_test = split_data_labels_neuroticism(csv_file)

# %%
import pandas as pd
import xgboost as xgb
from sklearn.model_selection import GridSearchCV

data = pd.read_csv("complete_CSV_Train.csv")

X, y = x_train, y_train
    
params = { 'max_depth': [3,6,10],
           'learning_rate': [0.01, 0.05, 0.1],
           'n_estimators': [100, 500, 1000],
           'colsample_bytree': [0.3, 0.7]}

xgbr = xgb.XGBRegressor(seed = 20)
clf = GridSearchCV(estimator=xgbr, 
                   param_grid=params,
                   scoring='neg_mean_absolute_error', 
                   verbose=1)

clf.fit(X, y)
print("Best parameters:", clf.best_params_)
print("Lowest mae: ", (-clf.best_score_)**(1/2.0))
# Out:
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# Best parameters: {'colsample_bytree': 0.7, 'learning_rate': 0.01, 'max_depth': 10, 'n_estimators': 1000}
# Lowest mae:  0.32288664907224823

# %%
from xgboost import XGBRegressor

xgbr = XGBRegressor(colsample_bytree = 0.3, learning_rate = 0.01, max_depth = 10, n_estimators = 1000, verbosity=0)
print(xgbr)
# Out:
# XGBRegressor(base_score=None, booster=None, colsample_bylevel=None,
#              colsample_bynode=None, colsample_bytree=0.3, gamma=None,
#              gpu_id=None, importance_type='gain', interaction_constraints=None,
#              learning_rate=0.01, max_delta_step=None, max_depth=10,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=1000, n_jobs=None, num_parallel_tree=None,
#              random_state=None, reg_alpha=None, reg_lambda=None,
#              scale_pos_weight=None, subsample=None, tree_method=None,
#              validate_parameters=None, verbosity=0)

# %%
xgbr.fit(x_train, y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.3, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.01, max_delta_step=0, max_depth=10,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=1000, n_jobs=8, num_parallel_tree=1, random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=0)

# %%
score = xgbr.score(x_train, y_train)
print(score)
# Out:
# 0.997078789312331

# %%
from xgboost import XGBRegressor
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error


cv_score = cross_val_score(xgbr, x_train, y_train, cv=10)
print("CV mean score:", cv_score.mean())
# Out:
# CV mean score: 0.27151118317538137

# %%
ypred = xgbr.predict(x_test)
mae = mean_absolute_error(y_test, ypred)

print("1-MAE", 1-mae)
# Out:
# 1-MAE 0.8980731093883514

# %%
csv_file = "complete_CSV_Train.csv"
x_train, y_train = split_data_labels(csv_file)
csv_file = "complete_CSV_validation.csv"
x_test, y_test = split_data_labels(csv_file)

# %%
import math
import numpy as np
import pandas as pd
import os
import glob
import pickle
import xgboost as xgb
import numpy as np
import pandas as pd
from sklearn.metrics import mutual_info_score

# %%
def split_data_labels_neuroticism (csv_file):
    df = pd.read_csv(csv_file)
    #display(df)
    x_array = df.iloc[:,1:-6]
    #print(df1)
    y_array = df.iloc[:,229]
    return x_array, y_array
    #print(result)

# %%
csv_file = "complete_CSV_Train.csv"
x_train, y_train = split_data_labels_neuroticism(csv_file)
csv_file = "complete_CSV_validation.csv"
x_test, y_test = split_data_labels_neuroticism(csv_file)

#X = x_train
y = y_train
print(y_train)
# Out:
# 0       0.322917
# 1       0.687500
# 2       0.843750
# 3       0.447917
# 4       0.333333
#           ...
# 5995    0.645833
# 5996    0.364583
# 5997    0.489583
# 5998    0.468750
# 5999    0.291667
# Name: Neuroticism, Length: 6000, dtype: float64

# %%
x_test_best10 = x_test.iloc[:, 130]
x_test_best10 = pd.concat([x_test_best10, x_test.iloc[:, 42]], axis=1).reindex(x_test_best10.index)
x_test_best10 = pd.concat([x_test_best10, x_test.iloc[:, 212]], axis=1).reindex(x_test_best10.index)
x_test_best10 = pd.concat([x_test_best10, x_test.iloc[:, 72]], axis=1).reindex(x_test_best10.index)
x_test_best10 = pd.concat([x_test_best10, x_test.iloc[:, 178]], axis=1).reindex(x_test_best10.index)
x_test_best10 = pd.concat([x_test_best10, x_test.iloc[:, 184]], axis=1).reindex(x_test_best10.index)
x_test_best10 = pd.concat([x_test_best10, x_test.iloc[:, 61]], axis=1).reindex(x_test_best10.index)
x_test_best10 = pd.concat([x_test_best10, x_test.iloc[:, 74]], axis=1).reindex(x_test_best10.index)
x_test_best10 = pd.concat([x_test_best10, x_test.iloc[:, 73]], axis=1).reindex(x_test_best10.index)
x_test_best10 = pd.concat([x_test_best10, x_test.iloc[:, 8]], axis=1).reindex(x_test_best10.index)
display(x_test_best10)
x_test = x_test_best10
# Out:
#       10_average   AU12_c_present  left_eye_corner_max      20_max  \
# 0      41.035706         0.381201            66.200680  197.159794
# 1      34.242781         0.000000            63.924956   86.379862
# 2      16.239556         0.202614            42.516938   82.356133
# 3      40.148859         0.000000            56.011606   99.603596
# 4      13.674574         0.130548            35.500563   66.324476
# ...          ...              ...                  ...         ...
# 1995   15.079767         0.223433            32.936909   43.544913
# 1996   13.403361         0.503268            45.692122   64.748209
# 1997   12.482461         0.080940            42.147479   25.802000
# 1998   15.541574         0.370757            40.569077   46.431133
# 1999   13.794485         0.180157            41.904296   28.800244
#
#       58_average  64_average       9_max      22_max      21_max   AU12_r_max
# 0      53.347194   48.043457  118.217350  185.316358  194.333834         2.07
# ...

# %%
x_train_best10 = X.iloc[:, 130]
x_train_best10 = pd.concat([x_train_best10, X.iloc[:, 42]], axis=1).reindex(x_train_best10.index)
x_train_best10 = pd.concat([x_train_best10, X.iloc[:, 212]], axis=1).reindex(x_train_best10.index)
x_train_best10 = pd.concat([x_train_best10, X.iloc[:, 72]], axis=1).reindex(x_train_best10.index)
x_train_best10 = pd.concat([x_train_best10, X.iloc[:, 178]], axis=1).reindex(x_train_best10.index)
x_train_best10 = pd.concat([x_train_best10, X.iloc[:, 184]], axis=1).reindex(x_train_best10.index)
x_train_best10 = pd.concat([x_train_best10, X.iloc[:, 61]], axis=1).reindex(x_train_best10.index)
x_train_best10 = pd.concat([x_train_best10, X.iloc[:, 74]], axis=1).reindex(x_train_best10.index)
x_train_best10 = pd.concat([x_train_best10, X.iloc[:, 73]], axis=1).reindex(x_train_best10.index)
x_train_best10 = pd.concat([x_train_best10, X.iloc[:, 8]], axis=1).reindex(x_train_best10.index)

display(x_train_best10)
# Out:
#       10_average   AU12_c_present  left_eye_corner_max      20_max  \
# 0      69.714035         0.059211            43.852594  644.285040
# 1      10.945691         0.185379            43.733054   29.381336
# 2      13.567198         0.989107            46.472788   47.801170
# 3      44.724500         0.481481            58.930637  111.461913
# 4      63.941103         0.002179            81.186021  297.506823
# ...          ...              ...                  ...         ...
# 5995   31.554197         0.161220            75.432089  131.437548
# 5996   24.532370         0.047930            40.471224   41.068194
# 5997   38.637180         0.268930            63.254170  168.414219
# 5998   55.898603         0.244009            61.531293   99.174575
# 5999   34.604363         0.008715            62.771411  186.331326
#
#       58_average  64_average       9_max      22_max      21_max   AU12_r_max
# 0      77.613532   76.298274  818.026564  699.275363  659.506891         2.04
# ...

# %%
x_train_best20 = x_train_best10
x_train_best20 = pd.concat([x_train_best20, X.iloc[:, 25]], axis=1).reindex(x_train_best20.index)
x_train_best20 = pd.concat([x_train_best20, X.iloc[:, 213]], axis=1).reindex(x_train_best20.index)
x_train_best20 = pd.concat([x_train_best20, X.iloc[:, 171]], axis=1).reindex(x_train_best20.index)
x_train_best20 = pd.concat([x_train_best20, X.iloc[:, 180]], axis=1).reindex(x_train_best20.index)
x_train_best20 = pd.concat([x_train_best20, X.iloc[:, 172]], axis=1).reindex(x_train_best20.index)
x_train_best20 = pd.concat([x_train_best20, X.iloc[:, 177]], axis=1).reindex(x_train_best20.index)
x_train_best20 = pd.concat([x_train_best20, X.iloc[:, 38]], axis=1).reindex(x_train_best20.index)
x_train_best20 = pd.concat([x_train_best20, X.iloc[:, 223]], axis=1).reindex(x_train_best20.index)
x_train_best20 = pd.concat([x_train_best20, X.iloc[:, 31]], axis=1).reindex(x_train_best20.index)
x_train_best20 = pd.concat([x_train_best20, X.iloc[:, 110]], axis=1).reindex(x_train_best20.index)
display(x_train_best20)
# Out:
#       10_average   AU12_c_present  left_eye_corner_max      20_max  \
# 0      69.714035         0.059211            43.852594  644.285040
# 1      10.945691         0.185379            43.733054   29.381336
# 2      13.567198         0.989107            46.472788   47.801170
# 3      44.724500         0.481481            58.930637  111.461913
# 4      63.941103         0.002179            81.186021  297.506823
# ...          ...              ...                  ...         ...
# 5995   31.554197         0.161220            75.432089  131.437548
# 5996   24.532370         0.047930            40.471224   41.068194
# 5997   38.637180         0.268930            63.254170  168.414219
# 5998   55.898603         0.244009            61.531293   99.174575
# 5999   34.604363         0.008715            62.771411  186.331326
#
#       58_average  64_average       9_max      22_max      21_max   AU12_r_max  \
# 0      77.613532   76.298274  818.026564  699.275363  659.506891         2.04
# ...

# %%
x_train_best30 = x_train_best20
x_train_best30 = pd.concat([x_train_best30, X.iloc[:, 27]], axis=1).reindex(x_train_best30.index)
x_train_best30 = pd.concat([x_train_best30, X.iloc[:, 100]], axis=1).reindex(x_train_best30.index)
x_train_best30 = pd.concat([x_train_best30, X.iloc[:, 6]], axis=1).reindex(x_train_best30.index)
x_train_best30 = pd.concat([x_train_best30, X.iloc[:, 71]], axis=1).reindex(x_train_best30.index)
x_train_best30 = pd.concat([x_train_best30, X.iloc[:, 76]], axis=1).reindex(x_train_best30.index)
x_train_best30 = pd.concat([x_train_best30, X.iloc[:, 118]], axis=1).reindex(x_train_best30.index)
x_train_best30 = pd.concat([x_train_best30, X.iloc[:, 7]], axis=1).reindex(x_train_best30.index)
x_train_best30 = pd.concat([x_train_best30, X.iloc[:, 115]], axis=1).reindex(x_train_best30.index)
x_train_best30 = pd.concat([x_train_best30, X.iloc[:, 41]], axis=1).reindex(x_train_best30.index)
x_train_best30 = pd.concat([x_train_best30, X.iloc[:, 105]], axis=1).reindex(x_train_best30.index)
display(x_train_best30)
# Out:
#       10_average   AU12_c_present  left_eye_corner_max      20_max  \
# 0      69.714035         0.059211            43.852594  644.285040
# 1      10.945691         0.185379            43.733054   29.381336
# 2      13.567198         0.989107            46.472788   47.801170
# 3      44.724500         0.481481            58.930637  111.461913
# 4      63.941103         0.002179            81.186021  297.506823
# ...          ...              ...                  ...         ...
# 5995   31.554197         0.161220            75.432089  131.437548
# 5996   24.532370         0.047930            40.471224   41.068194
# 5997   38.637180         0.268930            63.254170  168.414219
# 5998   55.898603         0.244009            61.531293   99.174575
# 5999   34.604363         0.008715            62.771411  186.331326
#
#       58_average  64_average       9_max      22_max      21_max   AU12_r_max  \
# 0      77.613532   76.298274  818.026564  699.275363  659.506891         2.04
# ...

# %%
x_train = x_train_best10
display(x_train)
# Out:
#       10_average   AU12_c_present  left_eye_corner_max      20_max  \
# 0      69.714035         0.059211            43.852594  644.285040
# 1      10.945691         0.185379            43.733054   29.381336
# 2      13.567198         0.989107            46.472788   47.801170
# 3      44.724500         0.481481            58.930637  111.461913
# 4      63.941103         0.002179            81.186021  297.506823
# ...          ...              ...                  ...         ...
# 5995   31.554197         0.161220            75.432089  131.437548
# 5996   24.532370         0.047930            40.471224   41.068194
# 5997   38.637180         0.268930            63.254170  168.414219
# 5998   55.898603         0.244009            61.531293   99.174575
# 5999   34.604363         0.008715            62.771411  186.331326
#
#       58_average  64_average       9_max      22_max      21_max   AU12_r_max
# 0      77.613532   76.298274  818.026564  699.275363  659.506891         2.04
# ...

# %%
import pandas as pd
import xgboost as xgb
from sklearn.model_selection import GridSearchCV

data = pd.read_csv("complete_CSV_Train.csv")

X, y = x_train, y_train
    
params = { 'max_depth': [3,6,10],
           'learning_rate': [0.01, 0.05, 0.1],
           'n_estimators': [100, 500, 1000],
           'colsample_bytree': [0.3, 0.7]}

xgbr = xgb.XGBRegressor(seed = 20)
clf = GridSearchCV(estimator=xgbr, 
                   param_grid=params,
                   scoring='neg_mean_absolute_error', 
                   verbose=1)

clf.fit(X, y)
print("Best parameters:", clf.best_params_)
print("Lowest mae: ", (-clf.best_score_)**(1/2.0))
# Out:
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# Best parameters: {'colsample_bytree': 0.7, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100}
# Lowest mae:  0.3405572284420708

# %%
from xgboost import XGBRegressor

xgbr = XGBRegressor(colsample_bytree = 0.7, learning_rate = 0.05, max_depth = 3, n_estimators = 100, verbosity=0)
print(xgbr)
# Out:
# XGBRegressor(base_score=None, booster=None, colsample_bylevel=None,
#              colsample_bynode=None, colsample_bytree=0.7, gamma=None,
#              gpu_id=None, importance_type='gain', interaction_constraints=None,
#              learning_rate=0.05, max_delta_step=None, max_depth=3,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              random_state=None, reg_alpha=None, reg_lambda=None,
#              scale_pos_weight=None, subsample=None, tree_method=None,
#              validate_parameters=None, verbosity=0)

# %%
xgbr.fit(x_train, y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.7, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.05, max_delta_step=0, max_depth=3,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=100, n_jobs=8, num_parallel_tree=1, random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=0)

# %%
print(x_train)
print(y_train)
# Out:
#       10_average   AU12_c_present  left_eye_corner_max      20_max  \
# 0      41.035706         0.381201            66.200680  197.159794
# 1      34.242781         0.000000            63.924956   86.379862
# 2      16.239556         0.202614            42.516938   82.356133
# 3      40.148859         0.000000            56.011606   99.603596
# 4      13.674574         0.130548            35.500563   66.324476
# ...          ...              ...                  ...         ...
# 1995   15.079767         0.223433            32.936909   43.544913
# 1996   13.403361         0.503268            45.692122   64.748209
# 1997   12.482461         0.080940            42.147479   25.802000
# 1998   15.541574         0.370757            40.569077   46.431133
# 1999   13.794485         0.180157            41.904296   28.800244
#
#       58_average  64_average       9_max      22_max      21_max   AU12_r_max
# 0      53.347194   48.043457  118.217350  185.316358  194.333834         2.07
# ...

# %%
score = xgbr.score(x_train, y_train)
print(score)
# Out:
# 0.17657724553598975

# %%
from xgboost import XGBRegressor
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error


cv_score = cross_val_score(xgbr, x_train, y_train, cv=10)
print("CV mean score:", cv_score.mean())
# Out:
# CV mean score: 0.11628702089023894

# %%
ypred = xgbr.predict(x_test)
mae = mean_absolute_error(y_test, ypred)

print("1-MAE", 1-mae)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\ERIKBU~1\AppData\Local\Temp/ipykernel_11320/925415336.py in <module>
# ----> 1 ypred = xgbr.predict(x_test)
#       2 mae = mean_absolute_error(y_test, ypred)
#       3
#       4 print("1-MAE", 1-mae)
#
# C:\Anaconda\envs\Thesis\lib\site-packages\xgboost\sklearn.py in predict(self, X, output_margin, ntree_limit, validate_features, base_margin, iteration_range)
#     818         if self._can_use_inplace_predict():
#     819             try:
# --> 820                 predts = self.get_booster().inplace_predict(
#     821                     data=X,
#     822                     iteration_range=iteration_range,
#
# C:\Anaconda\envs\Thesis\lib\site-packages\xgboost\core.py in inplace_predict(self, data, iteration_range, predict_type, missing, validate_features, base_margin, strict_shape)
# ...

# %%
print(x_test)
print(x_train)
# Out:
#       AU01_r_max   AU02_r_max   AU04_r_max   AU05_r_max   AU06_r_max  \
# 0           1.52         0.85         2.34         0.75         1.62
# 1           3.95         1.11         2.25         2.25         0.95
# 2           3.08         1.72         0.00         1.40         0.52
# 3           0.93         1.18         0.00         1.83         0.00
# 4           3.77         3.27         1.81         1.04         0.28
# ...          ...          ...          ...          ...          ...
# 1995        2.68         1.39         1.07         1.03         2.16
# 1996        2.58         1.30         1.26         1.24         1.73
# 1997        1.32         0.83         2.19         0.83         0.94
# 1998        1.57         1.11         1.92         2.10         1.31
# 1999        1.52         0.91         2.51         1.25         1.29
#
#        AU07_r_max   AU09_r_max   AU10_r_max   AU12_r_max   AU14_r_max  ...  \
# ...

# %%
def split_data_labels (csv_file):
    df = pd.read_csv(csv_file)
    #display(df)
    x_array = df.iloc[:,1:-6]
    #print(df1)
    y_array = df.iloc[:,230:]
    return x_array, y_array
    #print(result)

# %%
csv_file = "complete_CSV_Train.csv"
x_train, y_train = split_data_labels_neuroticism(csv_file)
csv_file = "complete_CSV_validation.csv"
x_test, y_test = split_data_labels_neuroticism(csv_file)

#X = x_train
#x_train = x_train_best10
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\ERIKBU~1\AppData\Local\Temp/ipykernel_24976/3095130823.py in <module>
#       1 csv_file = "complete_CSV_Train.csv"
# ----> 2 x_train, y_train = split_data_labels_neuroticism(csv_file)
#       3 csv_file = "complete_CSV_validation.csv"
#       4 x_test, y_test = split_data_labels_neuroticism(csv_file)
#       5
#
# NameError: name 'split_data_labels_neuroticism' is not defined

# %%
import pandas as pd
import xgboost as xgb
from sklearn.model_selection import GridSearchCV

data = pd.read_csv("complete_CSV_Train.csv")

X, y = x_train, y_train
    
params = { 'max_depth': [3,6,10],
           'learning_rate': [0.01, 0.05, 0.1],
           'n_estimators': [100, 500, 1000],
           'colsample_bytree': [0.3, 0.7]}

xgbr = xgb.XGBRegressor(seed = 20)
clf = GridSearchCV(estimator=xgbr, 
                   param_grid=params,
                   scoring='neg_mean_absolute_error', 
                   verbose=1)

clf.fit(X, y)
print("Best parameters:", clf.best_params_)
print("Lowest mae: ", (-clf.best_score_)**(1/2.0))
# Out:
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# Best parameters: {'colsample_bytree': 0.7, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100}
# Lowest mae:  0.3405572284420708

# %%
x_test_best10 = x_test.iloc[:, 130]
x_test_best10 = pd.concat([x_test_best10, x_test.iloc[:, 42]], axis=1).reindex(x_test_best10.index)
x_test_best10 = pd.concat([x_test_best10, x_test.iloc[:, 212]], axis=1).reindex(x_test_best10.index)
x_test_best10 = pd.concat([x_test_best10, x_test.iloc[:, 72]], axis=1).reindex(x_test_best10.index)
x_test_best10 = pd.concat([x_test_best10, x_test.iloc[:, 178]], axis=1).reindex(x_test_best10.index)
x_test_best10 = pd.concat([x_test_best10, x_test.iloc[:, 184]], axis=1).reindex(x_test_best10.index)
x_test_best10 = pd.concat([x_test_best10, x_test.iloc[:, 61]], axis=1).reindex(x_test_best10.index)
x_test_best10 = pd.concat([x_test_best10, x_test.iloc[:, 74]], axis=1).reindex(x_test_best10.index)
x_test_best10 = pd.concat([x_test_best10, x_test.iloc[:, 73]], axis=1).reindex(x_test_best10.index)
x_test_best10 = pd.concat([x_test_best10, x_test.iloc[:, 8]], axis=1).reindex(x_test_best10.index)
display(x_test_best10)
x_test = x_test_best10
# Out:
#       10_average   AU12_c_present  left_eye_corner_max      20_max  \
# 0      41.035706         0.381201            66.200680  197.159794
# 1      34.242781         0.000000            63.924956   86.379862
# 2      16.239556         0.202614            42.516938   82.356133
# 3      40.148859         0.000000            56.011606   99.603596
# 4      13.674574         0.130548            35.500563   66.324476
# ...          ...              ...                  ...         ...
# 1995   15.079767         0.223433            32.936909   43.544913
# 1996   13.403361         0.503268            45.692122   64.748209
# 1997   12.482461         0.080940            42.147479   25.802000
# 1998   15.541574         0.370757            40.569077   46.431133
# 1999   13.794485         0.180157            41.904296   28.800244
#
#       58_average  64_average       9_max      22_max      21_max   AU12_r_max
# 0      53.347194   48.043457  118.217350  185.316358  194.333834         2.07
# ...

# %%
from xgboost import XGBRegressor

xgbr = XGBRegressor(colsample_bytree = 0.7, learning_rate = 0.05, max_depth = 3, n_estimators = 100, verbosity=0)
print(xgbr)
# Out:
# XGBRegressor(base_score=None, booster=None, colsample_bylevel=None,
#              colsample_bynode=None, colsample_bytree=0.7, gamma=None,
#              gpu_id=None, importance_type='gain', interaction_constraints=None,
#              learning_rate=0.05, max_delta_step=None, max_depth=3,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              random_state=None, reg_alpha=None, reg_lambda=None,
#              scale_pos_weight=None, subsample=None, tree_method=None,
#              validate_parameters=None, verbosity=0)

# %%
xgbr.fit(x_train, y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.7, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.05, max_delta_step=0, max_depth=3,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=100, n_jobs=8, num_parallel_tree=1, random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=0)

# %%
score = xgbr.score(x_train, y_train)
print(score)
# Out:
# 0.17657724553598975

# %%
from xgboost import XGBRegressor
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error


cv_score = cross_val_score(xgbr, x_train, y_train, cv=10)
print("CV mean score:", cv_score.mean())
# Out:
# CV mean score: 0.11628702089023894

# %%
ypred = xgbr.predict(x_test)
mae = mean_absolute_error(y_test, ypred)

print("1-MAE", 1-mae)
# Out:
# 1-MAE 0.8877377895613512

# %%
def split_data_labels (csv_file):
    df = pd.read_csv(csv_file)
    #display(df)
    x_array = df.iloc[:,1:-6]
    #print(df1)
    y_array = df.iloc[:,230:]
    return x_array, y_array
    #print(result)

# %%
csv_file = "complete_CSV_Train.csv"
x_train, y_train = split_data_labels_neuroticism(csv_file)
csv_file = "complete_CSV_validation.csv"
x_test, y_test = split_data_labels_neuroticism(csv_file)

#X = x_train
x_train = x_train_best20

# %%
import pandas as pd
import xgboost as xgb
from sklearn.model_selection import GridSearchCV

data = pd.read_csv("complete_CSV_Train.csv")

X, y = x_train, y_train
    
params = { 'max_depth': [3,6,10],
           'learning_rate': [0.01, 0.05, 0.1],
           'n_estimators': [100, 500, 1000],
           'colsample_bytree': [0.3, 0.7]}

xgbr = xgb.XGBRegressor(seed = 20)
clf = GridSearchCV(estimator=xgbr, 
                   param_grid=params,
                   scoring='neg_mean_absolute_error', 
                   verbose=1)

clf.fit(X, y)
print("Best parameters:", clf.best_params_)
print("Lowest mae: ", (-clf.best_score_)**(1/2.0))
# Out:
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# Best parameters: {'colsample_bytree': 0.7, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# Lowest mae:  0.3393134710119952

# %%
x_test_best20 = x_test_best10
x_test_best20 = pd.concat([x_test_best20, x_test.iloc[:, 25]], axis=1).reindex(x_test_best20.index)
x_test_best20 = pd.concat([x_test_best20, x_test.iloc[:, 213]], axis=1).reindex(x_test_best20.index)
x_test_best20 = pd.concat([x_test_best20, x_test.iloc[:, 171]], axis=1).reindex(x_test_best20.index)
x_test_best20 = pd.concat([x_test_best20, x_test.iloc[:, 180]], axis=1).reindex(x_test_best20.index)
x_test_best20 = pd.concat([x_test_best20, x_test.iloc[:, 172]], axis=1).reindex(x_test_best20.index)
x_test_best20 = pd.concat([x_test_best20, x_test.iloc[:, 177]], axis=1).reindex(x_test_best20.index)
x_test_best20 = pd.concat([x_test_best20, x_test.iloc[:, 38]], axis=1).reindex(x_test_best20.index)
x_test_best20 = pd.concat([x_test_best20, x_test.iloc[:, 223]], axis=1).reindex(x_test_best20.index)
x_test_best20 = pd.concat([x_test_best20, x_test.iloc[:, 31]], axis=1).reindex(x_test_best20.index)
x_test_best20 = pd.concat([x_test_best20, x_test.iloc[:, 110]], axis=1).reindex(x_test_best20.index)
display(x_test_best20)
x_test = x_test_best20
# Out:
#       10_average   AU12_c_present  left_eye_corner_max      20_max  \
# 0      41.035706         0.381201            66.200680  197.159794
# 1      34.242781         0.000000            63.924956   86.379862
# 2      16.239556         0.202614            42.516938   82.356133
# 3      40.148859         0.000000            56.011606   99.603596
# 4      13.674574         0.130548            35.500563   66.324476
# ...          ...              ...                  ...         ...
# 1995   15.079767         0.223433            32.936909   43.544913
# 1996   13.403361         0.503268            45.692122   64.748209
# 1997   12.482461         0.080940            42.147479   25.802000
# 1998   15.541574         0.370757            40.569077   46.431133
# 1999   13.794485         0.180157            41.904296   28.800244
#
#       58_average  64_average       9_max      22_max      21_max   AU12_r_max  \
# 0      53.347194   48.043457  118.217350  185.316358  194.333834         2.07
# ...

# %%
from xgboost import XGBRegressor

xgbr = XGBRegressor(colsample_bytree = 0.7, learning_rate = 0.1, max_depth = 3, n_estimators = 1000, verbosity=0)
print(xgbr)
# Out:
# XGBRegressor(base_score=None, booster=None, colsample_bylevel=None,
#              colsample_bynode=None, colsample_bytree=0.7, gamma=None,
#              gpu_id=None, importance_type='gain', interaction_constraints=None,
#              learning_rate=0.1, max_delta_step=None, max_depth=3,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=1000, n_jobs=None, num_parallel_tree=None,
#              random_state=None, reg_alpha=None, reg_lambda=None,
#              scale_pos_weight=None, subsample=None, tree_method=None,
#              validate_parameters=None, verbosity=0)

# %%
xgbr.fit(x_train, y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.7, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.1, max_delta_step=0, max_depth=3,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=1000, n_jobs=8, num_parallel_tree=1, random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=0)

# %%
score = xgbr.score(x_train, y_train)
print(score)
# Out:
# 0.6316689519365186

# %%
from xgboost import XGBRegressor
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error


cv_score = cross_val_score(xgbr, x_train, y_train, cv=10)
print("CV mean score:", cv_score.mean())
# Out:
# CV mean score: 0.0644713824615217

# %%
ypred = xgbr.predict(x_test)
mae = mean_absolute_error(y_test, ypred)

print("1-MAE", 1-mae)
# Out:
# 1-MAE 0.887174718345205

# %%
def split_data_labels (csv_file):
    df = pd.read_csv(csv_file)
    #display(df)
    x_array = df.iloc[:,1:-6]
    #print(df1)
    y_array = df.iloc[:,230:]
    return x_array, y_array
    #print(result)

# %%
csv_file = "complete_CSV_Train.csv"
x_train, y_train = split_data_labels_neuroticism(csv_file)
csv_file = "complete_CSV_validation.csv"
x_test, y_test = split_data_labels_neuroticism(csv_file)

#X = x_train
X = x_train_best30
y = y_train

# %%
import pandas as pd
import xgboost as xgb
from sklearn.model_selection import GridSearchCV

data = pd.read_csv("complete_CSV_Train.csv")

X, y = x_train, y_train
    
params = { 'max_depth': [3,6,10],
           'learning_rate': [0.01, 0.05, 0.1],
           'n_estimators': [100, 500, 1000],
           'colsample_bytree': [0.3, 0.7]}

xgbr = xgb.XGBRegressor(seed = 20)
clf = GridSearchCV(estimator=xgbr, 
                   param_grid=params,
                   scoring='neg_mean_absolute_error', 
                   verbose=1)

clf.fit(X, y)
print("Best parameters:", clf.best_params_)
print("Lowest mae: ", (-clf.best_score_)**(1/2.0))
# Out:
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# Best parameters: {'colsample_bytree': 0.7, 'learning_rate': 0.01, 'max_depth': 10, 'n_estimators': 1000}
# Lowest mae:  0.32288664907224823

# %%
x_test_best30 = x_test_best20
x_test_best30 = pd.concat([x_test_best30, x_test.iloc[:, 27]], axis=1).reindex(x_test_best30.index)
x_test_best30 = pd.concat([x_test_best30, x_test.iloc[:, 100]], axis=1).reindex(x_test_best30.index)
x_test_best30 = pd.concat([x_test_best30, x_test.iloc[:, 6]], axis=1).reindex(x_test_best30.index)
x_test_best30 = pd.concat([x_test_best30, x_test.iloc[:, 71]], axis=1).reindex(x_test_best30.index)
x_test_best30 = pd.concat([x_test_best30, x_test.iloc[:, 76]], axis=1).reindex(x_test_best30.index)
x_test_best30 = pd.concat([x_test_best30, x_test.iloc[:, 118]], axis=1).reindex(x_test_best30.index)
x_test_best30 = pd.concat([x_test_best30, x_test.iloc[:, 7]], axis=1).reindex(x_test_best30.index)
x_test_best30 = pd.concat([x_test_best30, x_test.iloc[:, 115]], axis=1).reindex(x_test_best30.index)
x_test_best30 = pd.concat([x_test_best30, x_test.iloc[:, 41]], axis=1).reindex(x_test_best30.index)
x_test_best30 = pd.concat([x_test_best30, x_test.iloc[:, 105]], axis=1).reindex(x_test_best30.index)
display(x_test_best30)
x_test = x_test_best30
# Out:
#       10_average   AU12_c_present  left_eye_corner_max      20_max  \
# 0      41.035706         0.381201            66.200680  197.159794
# 1      34.242781         0.000000            63.924956   86.379862
# 2      16.239556         0.202614            42.516938   82.356133
# 3      40.148859         0.000000            56.011606   99.603596
# 4      13.674574         0.130548            35.500563   66.324476
# ...          ...              ...                  ...         ...
# 1995   15.079767         0.223433            32.936909   43.544913
# 1996   13.403361         0.503268            45.692122   64.748209
# 1997   12.482461         0.080940            42.147479   25.802000
# 1998   15.541574         0.370757            40.569077   46.431133
# 1999   13.794485         0.180157            41.904296   28.800244
#
#       58_average  64_average       9_max      22_max      21_max   AU12_r_max  \
# 0      53.347194   48.043457  118.217350  185.316358  194.333834         2.07
# ...

# %%
print(x_test)
# Out:
#       10_average   AU12_c_present  left_eye_corner_max      20_max  \
# 0      41.035706         0.381201            66.200680  197.159794
# 1      34.242781         0.000000            63.924956   86.379862
# 2      16.239556         0.202614            42.516938   82.356133
# 3      40.148859         0.000000            56.011606   99.603596
# 4      13.674574         0.130548            35.500563   66.324476
# ...          ...              ...                  ...         ...
# 1995   15.079767         0.223433            32.936909   43.544913
# 1996   13.403361         0.503268            45.692122   64.748209
# 1997   12.482461         0.080940            42.147479   25.802000
# 1998   15.541574         0.370757            40.569077   46.431133
# 1999   13.794485         0.180157            41.904296   28.800244
#
#       58_average  64_average       9_max      22_max      21_max   AU12_r_max  \
# 0      53.347194   48.043457  118.217350  185.316358  194.333834         2.07
# ...

# %%
from xgboost import XGBRegressor

xgbr = XGBRegressor(colsample_bytree = 0.7, learning_rate = 0.01, max_depth = 10, n_estimators = 1000, verbosity=0)
print(xgbr)
# Out:
# XGBRegressor(base_score=None, booster=None, colsample_bylevel=None,
#              colsample_bynode=None, colsample_bytree=0.7, gamma=None,
#              gpu_id=None, importance_type='gain', interaction_constraints=None,
#              learning_rate=0.01, max_delta_step=None, max_depth=10,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=1000, n_jobs=None, num_parallel_tree=None,
#              random_state=None, reg_alpha=None, reg_lambda=None,
#              scale_pos_weight=None, subsample=None, tree_method=None,
#              validate_parameters=None, verbosity=0)

# %%
xgbr.fit(x_train, y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.7, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.01, max_delta_step=0, max_depth=10,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=1000, n_jobs=8, num_parallel_tree=1, random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=0)

# %%
score = xgbr.score(x_train, y_train)
print(score)
# Out:
# 0.9956447678755285

# %%
from xgboost import XGBRegressor
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error


cv_score = cross_val_score(xgbr, x_train, y_train, cv=10)
print("CV mean score:", cv_score.mean())
# Out:
# CV mean score: 0.2688447401865416

# %%
ypred = xgbr.predict(x_test)
mae = mean_absolute_error(y_test, ypred)

print("1-MAE", 1-mae)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\ERIKBU~1\AppData\Local\Temp/ipykernel_11320/925415336.py in <module>
# ----> 1 ypred = xgbr.predict(x_test)
#       2 mae = mean_absolute_error(y_test, ypred)
#       3
#       4 print("1-MAE", 1-mae)
#
# C:\Anaconda\envs\Thesis\lib\site-packages\xgboost\sklearn.py in predict(self, X, output_margin, ntree_limit, validate_features, base_margin, iteration_range)
#     818         if self._can_use_inplace_predict():
#     819             try:
# --> 820                 predts = self.get_booster().inplace_predict(
#     821                     data=X,
#     822                     iteration_range=iteration_range,
#
# C:\Anaconda\envs\Thesis\lib\site-packages\xgboost\core.py in inplace_predict(self, data, iteration_range, predict_type, missing, validate_features, base_margin, strict_shape)
# ...

# %%
import math
import numpy as np
import pandas as pd
import os
import glob
import pickle
import xgboost as xgb
import numpy as np
import pandas as pd
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.feature_selection import f_regression
from sklearn.feature_selection import mutual_info_regression

# %%
listbestvalues = [130, 212, 178, 42, 74, 25, 8, 171, 184, 72, 31, 180, 172, 61, 73, 177, 223, 192, 125, 110, 142, 213, 181, 19, 100, 76, 27, 36, 163, 7, 187, 59, 126, 109, 111, 123, 41, 158, 115, 120, 71, 79, 11, 15, 208, 118, 102, 75, 112, 176, 195, 209, 121, 105, 222, 136, 220, 16, 124, 80, 108, 191, 30, 54, 185, 168, 210, 37, 52, 117, 201, 221, 205, 190, 81, 99, 60, 182, 38, 198, 131, 165, 207, 197, 33, 173, 83, 43, 29, 186, 32, 68, 66, 129, 216, 96, 103, 24, 206, 89, 174, 2, 166, 98, 22, 132, 65, 62, 3, 95, 157, 57, 6, 17, 67, 70, 69, 85, 107, 134, 23, 188, 116, 194, 13, 153, 82, 78, 56, 86, 156, 106, 119, 28, 55, 84, 128, 77, 179, 21, 164, 218, 170, 147, 211, 135, 154, 47, 150, 183, 141, 155, 138, 219, 160, 215, 26, 101, 104, 97, 93, 94, 203, 9, 151, 196, 58, 50, 167, 146, 87, 53, 4, 45, 35, 51, 127, 175, 159, 149, 10, 169, 193, 63, 162, 202, 92, 44, 204, 217, 214, 199, 200, 49, 5, 189, 48, 64, 46, 40, 39, 88, 90, 91, 34, 1, 113, 114, 122, 133, 137, 139, 140, 143, 144, 145, 148, 152, 20, 161, 18, 14, 12, 0]

# %%
print(listbestvalues)
# Out:
# [130, 212, 178, 42, 74, 25, 8, 171, 184, 72, 31, 180, 172, 61, 73, 177, 223, 192, 125, 110, 142, 213, 181, 19, 100, 76, 27, 36, 163, 7, 187, 59, 126, 109, 111, 123, 41, 158, 115, 120, 71, 79, 11, 15, 208, 118, 102, 75, 112, 176, 195, 209, 121, 105, 222, 136, 220, 16, 124, 80, 108, 191, 30, 54, 185, 168, 210, 37, 52, 117, 201, 221, 205, 190, 81, 99, 60, 182, 38, 198, 131, 165, 207, 197, 33, 173, 83, 43, 29, 186, 32, 68, 66, 129, 216, 96, 103, 24, 206, 89, 174, 2, 166, 98, 22, 132, 65, 62, 3, 95, 157, 57, 6, 17, 67, 70, 69, 85, 107, 134, 23, 188, 116, 194, 13, 153, 82, 78, 56, 86, 156, 106, 119, 28, 55, 84, 128, 77, 179, 21, 164, 218, 170, 147, 211, 135, 154, 47, 150, 183, 141, 155, 138, 219, 160, 215, 26, 101, 104, 97, 93, 94, 203, 9, 151, 196, 58, 50, 167, 146, 87, 53, 4, 45, 35, 51, 127, 175, 159, 149, 10, 169, 193, 63, 162, 202, 92, 44, 204, 217, 214, 199, 200, 49, 5, 189, 48, 64, 46, 40, 39, 88, 90, 91, 34, 1, 113, 114, 122, 133, 137, 139, 140, 143, 144, 145, 148, 152, 20, 161, 18
# ...

# %%
display(x_train)
display(x_test)
# Out:
#       AU01_r_max   AU02_r_max   AU04_r_max   AU05_r_max   AU06_r_max  \
# 0           2.00         3.32         1.40         2.89         1.16
# 1           2.81         1.76         1.36         1.51         0.95
# 2           1.16         1.19         1.40         1.20         1.84
# 3           1.51         1.22         0.43         2.27         1.23
# 4           3.42         2.76         3.08         1.83         0.66
# ...          ...          ...          ...          ...          ...
# 5995        2.20         1.38         0.00         1.47         1.65
# 5996        5.00         5.00         1.06         4.91         1.76
# 5997        1.99         1.36         0.09         0.79         1.00
# 5998        3.63         1.93         0.98         2.16         1.48
# 5999        3.32         3.97         0.41         1.09         0.60
#
#        AU07_r_max   AU09_r_max   AU10_r_max   AU12_r_max   AU14_r_max  ...  \
# ...

# %%
def bestfeatures (dfX, listbestvalues, wantedfeatures):
    output = pd.DataFrame(data=[])
    for i in range (0, wantedfeatures):
        output = pd.concat([output, dfX.iloc[:, listbestvalues[i]]], axis = 1).reindex(dfX.index)
    return output

# %%
x_train_best100 = bestfeatures(x_train, listbestvalues, 100)
display(x_train_best100)
x_test_best100 = bestfeatures(x_test, listbestvalues, 233)
display(x_test_best100)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\ERIKBU~1\AppData\Local\Temp/ipykernel_25204/1638700720.py in <module>
# ----> 1 x_train_best100 = bestfeatures(x_train, listbestvalues, 100)
#       2 display(x_train_best100)
#       3 x_test_best100 = bestfeatures(x_test, listbestvalues, 233)
#       4 display(x_test_best100)
#
# NameError: name 'x_train' is not defined

# %%
#x_train_best = x_train.iloc[:, listbestvalues[0]]
testdf = pd.DataFrame(data=[])
display(testdf)
pd.set_option('display.max_rows', 500)
test1 = pd.concat([testdf, x_train.iloc[:, 42]], axis=1).reindex(x_train.index)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# Out:
# As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead.
#
# : boolean
#     use_inf_as_null had been deprecated and will be removed in a future
#     version. Use `use_inf_as_na` instead.
# C:\Anaconda\envs\Thesis\lib\site-packages\pandas\_config\config.py:630: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead.
#   warnings.warn(d.msg, FutureWarning)
# C:\Anaconda\envs\Thesis\lib\site-packages\pandas\_config\config.py:630: FutureWarning:
# : boolean
#     use_inf_as_null had been deprecated and will be removed in a future
#     version. Use `use_inf_as_na` instead.
#
#   warnings.warn(d.msg, FutureWarning)

# %%
x_train_best10 = X.iloc[:, 130]
x_train_best10 = pd.concat([x_train_best10, X.iloc[:, 42]], axis=1).reindex(x_train_best10.index)
x_train_best10 = pd.concat([x_train_best10, X.iloc[:, 212]], axis=1).reindex(x_train_best10.index)
x_train_best10 = pd.concat([x_train_best10, X.iloc[:, 72]], axis=1).reindex(x_train_best10.index)
x_train_best10 = pd.concat([x_train_best10, X.iloc[:, 178]], axis=1).reindex(x_train_best10.index)
x_train_best10 = pd.concat([x_train_best10, X.iloc[:, 184]], axis=1).reindex(x_train_best10.index)
x_train_best10 = pd.concat([x_train_best10, X.iloc[:, 61]], axis=1).reindex(x_train_best10.index)
x_train_best10 = pd.concat([x_train_best10, X.iloc[:, 74]], axis=1).reindex(x_train_best10.index)
x_train_best10 = pd.concat([x_train_best10, X.iloc[:, 73]], axis=1).reindex(x_train_best10.index)
x_train_best10 = pd.concat([x_train_best10, X.iloc[:, 8]], axis=1).reindex(x_train_best10.index)

display(x_train_best10)

# %%
def split_data_labels_interview (csv_file):
    df = pd.read_csv(csv_file)
    #display(df)
    x_array = df.iloc[:,1:-6]
    #print(df1)
    y_array = df.iloc[:,230:]
    return x_array, y_array
    #print(result)

# %%
listbestvalues = [130, 212, 178, 42, 74, 25, 8, 171, 184, 72, 31, 180, 172, 61, 73, 177, 223, 192, 125, 110, 142, 213, 181, 19, 100, 76, 27, 36, 163, 7, 187, 59, 126, 109, 111, 123, 41, 158, 115, 120, 71, 79, 11, 15, 208, 118, 102, 75, 112, 176, 195, 209, 121, 105, 222, 136, 220, 16, 124, 80, 108, 191, 30, 54, 185, 168, 210, 37, 52, 117, 201, 221, 205, 190, 81, 99, 60, 182, 38, 198, 131, 165, 207, 197, 33, 173, 83, 43, 29, 186, 32, 68, 66, 129, 216, 96, 103, 24, 206, 89, 174, 2, 166, 98, 22, 132, 65, 62, 3, 95, 157, 57, 6, 17, 67, 70, 69, 85, 107, 134, 23, 188, 116, 194, 13, 153, 82, 78, 56, 86, 156, 106, 119, 28, 55, 84, 128, 77, 179, 21, 164, 218, 170, 147, 211, 135, 154, 47, 150, 183, 141, 155, 138, 219, 160, 215, 26, 101, 104, 97, 93, 94, 203, 9, 151, 196, 58, 50, 167, 146, 87, 53, 4, 45, 35, 51, 127, 175, 159, 149, 10, 169, 193, 63, 162, 202, 92, 44, 204, 217, 214, 199, 200, 49, 5, 189, 48, 64, 46, 40, 39, 88, 90, 91, 34, 1, 113, 114, 122, 133, 137, 139, 140, 143, 144, 145, 148, 152, 20, 161, 18, 14, 12, 0]

# %%
def bestfeatures (dfX, listbestvalues, wantedfeatures):
    output = pd.DataFrame(data=[])
    for i in range (0, wantedfeatures):
        output = pd.concat([output, dfX.iloc[:, listbestvalues[i]]], axis = 1).reindex(dfX.index)
    return output

# %%
csv_file = "complete_CSV_Train.csv"
x_train, y_train = split_data_labels_interview(csv_file)
csv_file = "complete_CSV_validation.csv"
x_test, y_test = split_data_labels_interview(csv_file)

# %%
x_train_100 = bestfeatures(x_train, listbestvalues, 100)
x_test_100 = bestfeatures(x_test, listbestvalues, 100)

# %%
import pandas as pd
import xgboost as xgb
from sklearn.model_selection import GridSearchCV

data = pd.read_csv("complete_CSV_Train.csv")

X, y = x_train_100, y_train #1
    
params = { 'max_depth': [3,6,10],
           'learning_rate': [0.01, 0.05, 0.1],
           'n_estimators': [100, 500, 1000],
           'colsample_bytree': [0.3, 0.7]}

xgbr = xgb.XGBRegressor(seed = 20)
clf = GridSearchCV(estimator=xgbr, 
                   param_grid=params,
                   scoring='neg_mean_absolute_error', 
                   verbose=1)

clf.fit(X, y)
print("Best parameters:", clf.best_params_)
print("Lowest mae: ", (-clf.best_score_)**(1/2.0))
# Out:
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# Best parameters: {'colsample_bytree': 0.7, 'learning_rate': 0.01, 'max_depth': 10, 'n_estimators': 1000}
# Lowest mae:  0.32261249859942387

# %%
from xgboost import XGBRegressor

xgbr = XGBRegressor(colsample_bytree = 0.7, learning_rate = 0.01, max_depth = 10, n_estimators = 1000, verbosity=0)
print(xgbr)
# Out:
# XGBRegressor(base_score=None, booster=None, colsample_bylevel=None,
#              colsample_bynode=None, colsample_bytree=0.7, gamma=None,
#              gpu_id=None, importance_type='gain', interaction_constraints=None,
#              learning_rate=0.01, max_delta_step=None, max_depth=10,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=1000, n_jobs=None, num_parallel_tree=None,
#              random_state=None, reg_alpha=None, reg_lambda=None,
#              scale_pos_weight=None, subsample=None, tree_method=None,
#              validate_parameters=None, verbosity=0)

# %%
xgbr.fit(x_train_100, y_train) #2
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.7, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.01, max_delta_step=0, max_depth=10,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=1000, n_jobs=8, num_parallel_tree=1, random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=0)

# %%
score = xgbr.score(x_train_100, y_train) #3
print(score)
# Out:
# 0.9861580796769759

# %%
from xgboost import XGBRegressor
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error


cv_score = cross_val_score(xgbr, x_train_100, y_train, cv=10) #4
print("CV mean score:", cv_score.mean())
# Out:
# CV mean score: 0.249917926132529

# %%
ypred = xgbr.predict(x_test_100) #5
mae = mean_absolute_error(y_test, ypred)

print("1-MAE", 1-mae)
# Out:
# 1-MAE 0.9002386355787237

# %%
x_train_150 = bestfeatures(x_train, listbestvalues, 150)
x_test_150 = bestfeatures(x_test, listbestvalues, 150)

# %%
import pandas as pd
import xgboost as xgb
from sklearn.model_selection import GridSearchCV

data = pd.read_csv("complete_CSV_Train.csv")

X, y = x_train_150, y_train #1
    
params = { 'max_depth': [3,6,10],
           'learning_rate': [0.01, 0.05, 0.1],
           'n_estimators': [100, 500, 1000],
           'colsample_bytree': [0.3, 0.7]}

xgbr = xgb.XGBRegressor(seed = 20)
clf = GridSearchCV(estimator=xgbr, 
                   param_grid=params,
                   scoring='neg_mean_absolute_error', 
                   verbose=1)

clf.fit(X, y)
print("Best parameters:", clf.best_params_)
print("Lowest mae: ", (-clf.best_score_)**(1/2.0))
# Out:
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# Best parameters: {'colsample_bytree': 0.3, 'learning_rate': 0.01, 'max_depth': 6, 'n_estimators': 1000}
# Lowest mae:  0.32204578704233966

# %%
from xgboost import XGBRegressor

xgbr = XGBRegressor(colsample_bytree = 0.3, learning_rate = 0.01, max_depth = 6, n_estimators = 1000, verbosity=0)
print(xgbr)
# Out:
# XGBRegressor(base_score=None, booster=None, colsample_bylevel=None,
#              colsample_bynode=None, colsample_bytree=0.3, gamma=None,
#              gpu_id=None, importance_type='gain', interaction_constraints=None,
#              learning_rate=0.01, max_delta_step=None, max_depth=6,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=1000, n_jobs=None, num_parallel_tree=None,
#              random_state=None, reg_alpha=None, reg_lambda=None,
#              scale_pos_weight=None, subsample=None, tree_method=None,
#              validate_parameters=None, verbosity=0)

# %%
xgbr.fit(x_train_150, y_train) #2
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.3, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.01, max_delta_step=0, max_depth=6,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=1000, n_jobs=8, num_parallel_tree=1, random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=0)

# %%
score = xgbr.score(x_train_150, y_train) #3
print(score)
# Out:
# 0.7259566861342684

# %%
from xgboost import XGBRegressor
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error


cv_score = cross_val_score(xgbr, x_train_150, y_train, cv=10) #4
print("CV mean score:", cv_score.mean())
# Out:
# CV mean score: 0.2543398039860384

# %%
ypred = xgbr.predict(x_test_150) #5
mae = mean_absolute_error(y_test, ypred)

print("1-MAE", 1-mae)
# Out:
# 1-MAE 0.9001435740585918

# %%
x_train_50 = bestfeatures(x_train, listbestvalues, 50)
x_test_50 = bestfeatures(x_test, listbestvalues, 50)

# %%
import pandas as pd
import xgboost as xgb
from sklearn.model_selection import GridSearchCV

data = pd.read_csv("complete_CSV_Train.csv")

X, y = x_train_50, y_train #1
    
params = { 'max_depth': [3,6,10],
           'learning_rate': [0.01, 0.05, 0.1],
           'n_estimators': [100, 500, 1000],
           'colsample_bytree': [0.3, 0.7]}

xgbr = xgb.XGBRegressor(seed = 20)
clf = GridSearchCV(estimator=xgbr, 
                   param_grid=params,
                   scoring='neg_mean_absolute_error', 
                   verbose=1)

clf.fit(X, y)
print("Best parameters:", clf.best_params_)
print("Lowest mae: ", (-clf.best_score_)**(1/2.0))
# Out:
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# Best parameters: {'colsample_bytree': 0.7, 'learning_rate': 0.01, 'max_depth': 6, 'n_estimators': 1000}
# Lowest mae:  0.3295590131741892

# %%
from xgboost import XGBRegressor

xgbr = XGBRegressor(colsample_bytree = 0.7, learning_rate = 0.01, max_depth = 6, n_estimators = 1000, verbosity=0)
print(xgbr)
# Out:
# XGBRegressor(base_score=None, booster=None, colsample_bylevel=None,
#              colsample_bynode=None, colsample_bytree=0.7, gamma=None,
#              gpu_id=None, importance_type='gain', interaction_constraints=None,
#              learning_rate=0.01, max_delta_step=None, max_depth=6,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=1000, n_jobs=None, num_parallel_tree=None,
#              random_state=None, reg_alpha=None, reg_lambda=None,
#              scale_pos_weight=None, subsample=None, tree_method=None,
#              validate_parameters=None, verbosity=0)

# %%
xgbr.fit(x_train_50, y_train) #2
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.7, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.01, max_delta_step=0, max_depth=6,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=1000, n_jobs=8, num_parallel_tree=1, random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=0)

# %%
score = xgbr.score(x_train_50, y_train) #3
print(score)
# Out:
# 0.6520352596510494

# %%
from xgboost import XGBRegressor
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error


cv_score = cross_val_score(xgbr, x_train_50, y_train, cv=10) #4
print("CV mean score:", cv_score.mean())
# Out:
# CV mean score: 0.18552572548723106

# %%
ypred = xgbr.predict(x_test_50) #5
mae = mean_absolute_error(y_test, ypred)

print("1-MAE", 1-mae)
# Out:
# 1-MAE 0.8964567657292725

# %%
x_train_80 = bestfeatures(x_train, listbestvalues, 80)
x_test_80 = bestfeatures(x_test, listbestvalues, 80)

# %%
import pandas as pd
import xgboost as xgb
from sklearn.model_selection import GridSearchCV

data = pd.read_csv("complete_CSV_Train.csv")

X, y = x_train_80, y_train #1
    
params = { 'max_depth': [3,6,10],
           'learning_rate': [0.01, 0.05, 0.1],
           'n_estimators': [100, 500, 1000],
           'colsample_bytree': [0.3, 0.7]}

xgbr = xgb.XGBRegressor(seed = 20)
clf = GridSearchCV(estimator=xgbr, 
                   param_grid=params,
                   scoring='neg_mean_absolute_error', 
                   verbose=1)

clf.fit(X, y)
print("Best parameters:", clf.best_params_)
print("Lowest mae: ", (-clf.best_score_)**(1/2.0))
# Out:
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# Best parameters: {'colsample_bytree': 0.7, 'learning_rate': 0.01, 'max_depth': 10, 'n_estimators': 1000}
# Lowest mae:  0.3241981958525667

# %%
from xgboost import XGBRegressor

xgbr = XGBRegressor(colsample_bytree = 0.7, learning_rate = 0.01, max_depth = 10, n_estimators = 1000, verbosity=0)
print(xgbr)
# Out:
# XGBRegressor(base_score=None, booster=None, colsample_bylevel=None,
#              colsample_bynode=None, colsample_bytree=0.7, gamma=None,
#              gpu_id=None, importance_type='gain', interaction_constraints=None,
#              learning_rate=0.01, max_delta_step=None, max_depth=10,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=1000, n_jobs=None, num_parallel_tree=None,
#              random_state=None, reg_alpha=None, reg_lambda=None,
#              scale_pos_weight=None, subsample=None, tree_method=None,
#              validate_parameters=None, verbosity=0)

# %%
xgbr.fit(x_train_80, y_train) #2
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.7, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.01, max_delta_step=0, max_depth=10,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=1000, n_jobs=8, num_parallel_tree=1, random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=0)

# %%
score = xgbr.score(x_train_80, y_train) #3
print(score)
# Out:
# 0.984373591180292

# %%
from xgboost import XGBRegressor
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error


cv_score = cross_val_score(xgbr, x_train_80, y_train, cv=10) #4
print("CV mean score:", cv_score.mean())
# Out:
# CV mean score: 0.23877757118466492

# %%
ypred = xgbr.predict(x_test_80) #5
mae = mean_absolute_error(y_test, ypred)

print("1-MAE", 1-mae)
# Out:
# 1-MAE 0.8999929411506681

# %%
x_train_120 = bestfeatures(x_train, listbestvalues, 120)
x_test_120 = bestfeatures(x_test, listbestvalues, 120)

# %%
import pandas as pd
import xgboost as xgb
from sklearn.model_selection import GridSearchCV

data = pd.read_csv("complete_CSV_Train.csv")

X, y = x_train_120, y_train #1
    
params = { 'max_depth': [3,6,10],
           'learning_rate': [0.01, 0.05, 0.1],
           'n_estimators': [100, 500, 1000],
           'colsample_bytree': [0.3, 0.7]}

xgbr = xgb.XGBRegressor(seed = 20)
clf = GridSearchCV(estimator=xgbr, 
                   param_grid=params,
                   scoring='neg_mean_absolute_error', 
                   verbose=1)

clf.fit(X, y)
print("Best parameters:", clf.best_params_)
print("Lowest mae: ", (-clf.best_score_)**(1/2.0))
# Out:
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# Best parameters: {'colsample_bytree': 0.3, 'learning_rate': 0.01, 'max_depth': 6, 'n_estimators': 1000}
# Lowest mae:  0.32273137860869067

# %%
from xgboost import XGBRegressor

xgbr = XGBRegressor(colsample_bytree = 0.3, learning_rate = 0.01, max_depth = 6, n_estimators = 1000, verbosity=0)
print(xgbr)
# Out:
# XGBRegressor(base_score=None, booster=None, colsample_bylevel=None,
#              colsample_bynode=None, colsample_bytree=0.3, gamma=None,
#              gpu_id=None, importance_type='gain', interaction_constraints=None,
#              learning_rate=0.01, max_delta_step=None, max_depth=6,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=1000, n_jobs=None, num_parallel_tree=None,
#              random_state=None, reg_alpha=None, reg_lambda=None,
#              scale_pos_weight=None, subsample=None, tree_method=None,
#              validate_parameters=None, verbosity=0)

# %%
xgbr.fit(x_train_120, y_train) #2
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.3, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.01, max_delta_step=0, max_depth=6,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=1000, n_jobs=8, num_parallel_tree=1, random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=0)

# %%
score = xgbr.score(x_train_120, y_train) #3
print(score)
# Out:
# 0.717831498043336

# %%
from xgboost import XGBRegressor
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error


cv_score = cross_val_score(xgbr, x_train_120, y_train, cv=10) #4
print("CV mean score:", cv_score.mean())
# Out:
# CV mean score: 0.2496586684087206

# %%
ypred = xgbr.predict(x_test_120) #5
mae = mean_absolute_error(y_test, ypred)

print("1-MAE", 1-mae)
# Out:
# 1-MAE 0.8999523570411534

# %%
import pandas as pd
import xgboost as xgb
from sklearn.model_selection import GridSearchCV

data = pd.read_csv("complete_CSV_Train.csv")

X, y = x_train, y_train #1
    
params = { 'max_depth': [3,6,10],
           'learning_rate': [0.01, 0.05, 0.1],
           'n_estimators': [100, 500, 1000],
           'colsample_bytree': [0.3, 0.7]}

xgbr = xgb.XGBRegressor(seed = 20)
clf = GridSearchCV(estimator=xgbr, 
                   param_grid=params,
                   scoring='neg_mean_absolute_error', 
                   verbose=1)

clf.fit(X, y)
print("Best parameters:", clf.best_params_)
print("Lowest mae: ", (-clf.best_score_)**(1/2.0))
# Out:
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# Best parameters: {'colsample_bytree': 0.3, 'learning_rate': 0.01, 'max_depth': 6, 'n_estimators': 1000}
# Lowest mae:  0.32027520865923914

# %%
from xgboost import XGBRegressor

xgbr = XGBRegressor(colsample_bytree = 0.3, learning_rate = 0.01, max_depth = 6, n_estimators = 1000, verbosity=0)
print(xgbr)
# Out:
# XGBRegressor(base_score=None, booster=None, colsample_bylevel=None,
#              colsample_bynode=None, colsample_bytree=0.3, gamma=None,
#              gpu_id=None, importance_type='gain', interaction_constraints=None,
#              learning_rate=0.01, max_delta_step=None, max_depth=6,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=1000, n_jobs=None, num_parallel_tree=None,
#              random_state=None, reg_alpha=None, reg_lambda=None,
#              scale_pos_weight=None, subsample=None, tree_method=None,
#              validate_parameters=None, verbosity=0)

# %%
xgbr.fit(x_train, y_train) #2
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.3, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.01, max_delta_step=0, max_depth=6,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=1000, n_jobs=8, num_parallel_tree=1, random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=0)

# %%
score = xgbr.score(x_train, y_train) #3
print(score)
# Out:
# 0.7819262452824136

# %%
from xgboost import XGBRegressor
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error


cv_score = cross_val_score(xgbr, x_train, y_train, cv=10) #4
print("CV mean score:", cv_score.mean())
# Out:
# CV mean score: 0.2688914423622055

# %%
ypred = xgbr.predict(x_test) #5
mae = mean_absolute_error(y_test, ypred)

print("1-MAE", 1-mae)
# Out:
# 1-MAE 0.9015458303533286

# %%
x_train
# Out:
#       AU01_r_max   AU02_r_max   AU04_r_max   AU05_r_max   AU06_r_max  \
# 0           2.00         3.32         1.40         2.89         1.16
# 1           2.81         1.76         1.36         1.51         0.95
# 2           1.16         1.19         1.40         1.20         1.84
# 3           1.51         1.22         0.43         2.27         1.23
# 4           3.42         2.76         3.08         1.83         0.66
# ...          ...          ...          ...          ...          ...
# 5995        2.20         1.38         0.00         1.47         1.65
# 5996        5.00         5.00         1.06         4.91         1.76
# 5997        1.99         1.36         0.09         0.79         1.00
# 5998        3.63         1.93         0.98         2.16         1.48
# 5999        3.32         3.97         0.41         1.09         0.60
#
#        AU07_r_max   AU09_r_max   AU10_r_max   AU12_r_max   AU14_r_max  ...  \
# ...
